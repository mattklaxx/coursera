# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This course introduced you to multiple data science tools, and in this final project, you will use Jupyterlite Notebook, one of the easiest tools to share publicly.
#
# Leveraging Jupyterlite Notebook on Skills Network labs, you will create your Jupyterlite Notebook and share it via a public GitHub link.

# %% [markdown]
# Exercise 4 - Create a markdown cell to list data science languages. (3 pts)

# %% [markdown]
# Some popular data scientist languages are:
# 1.  Python
# 2.  R
# 3.  SQL

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)

# %% [markdown]
# Some of the commonly used libarries are:
# 1.  Scikit-learn
# 2.  Pytorch
# 3.  Tensorflow

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)

# %% [markdown]
# |Data Science Tools|
# |-----|
# |Anaconda|
# |R Studio|
# |Jupyter Notebooks|

# %% [markdown]
# ### The Cells below are going to multiply and add numbers

# %%
# The formula below adds 1+1

print(1+1)
# Out:
# 2

# %%
# The formula below multiplies 2*2 

print(2*2)
# Out:
# 4

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)

# %%
# The formula below converts 360 minutes to hours 

print(360/60)
# Out:
# 6.0

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)

# %% [markdown]
# ## Primary Objective
#     - Practice Markup Language
#     - Setup GitHub page
#     - Add comments to code

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)

# %% [markdown]
# Author: Matthew Scott

# %% [markdown]
# Exercise 12 - Share your notebook through GitHub (3 pts)

# %% [markdown]
# link = https://github.com/mattklaxx/coursera/blob/main/Data%20Science%20Tools%20and%20Ecosystem.ipynb

# %% [markdown]
# Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ![Screenshot%202023-03-03%20162408.png](attachment:Screenshot%202023-03-03%20162408.png)
